# %% [markdown]
# **Importing required Libraries**

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# **Loading the BITCOIN dataset**

# %%
bc=pd.read_csv('https://raw.githubusercontent.com/WidhyaOrg/datasets/master/bitcoin_dataset.csv')

# %% [markdown]
# **Visualizing the top three rows in the data**

# %%
bc.head(3)
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# 2                      0                           1.0
#
#    btc_median_confirmation_time  ...  btc_cost_per_transaction_percent  \
# 0                           0.0  ...                         31.781022
# 1                           0.0  ...                        154.463801
# ...

# %% [markdown]
# **Profiling the dataset summary**

# %%
bc.describe()
# Out:
#        btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# count       2906.000000        2.879000e+03    2.906000e+03      2.885000e+03
# mean         839.104218        1.151138e+07    1.344352e+10      7.398381e+07
# std         2304.972497        4.200024e+06    3.866841e+10      2.924228e+08
# min            0.000000        2.043200e+06    0.000000e+00      0.000000e+00
# 25%            6.653465        8.485300e+06    5.363081e+07      2.916456e+05
# 50%          235.130000        1.243115e+07    3.346869e+09      1.001414e+07
# 75%          594.191164        1.520051e+07    8.075525e+09      2.834038e+07
# max        19498.683330        1.683769e+07    3.270000e+11      5.352016e+09
#
#        btc_blocks_size  btc_avg_block_size  btc_n_orphaned_blocks  \
# count      2877.000000         2906.000000            2906.000000
# mean      35505.502848            0.350366               0.364074
# std       43618.633821            0.353168               0.842259
# ...

# %% [markdown]
# **Visualizing Jointplots between the Independet variable(btc_market_price) and the rest of independent variables**

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_total_bitcoins,data=bc, color='red')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_market_cap,data=bc, color='red')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_trade_volume,data=bc, color='red')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_blocks_size,data=bc,color='red')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_avg_block_size,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_n_orphaned_blocks,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_n_transactions_per_block,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_median_confirmation_time,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_hash_rate,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_difficulty,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_miners_revenue,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_transaction_fees,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_cost_per_transaction,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_n_unique_addresses,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_n_transactions,data=bc,color='green')

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_n_transactions_total,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_n_transactions_excluding_popular	,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_n_transactions_excluding_chains_longer_than_100,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_output_volume,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_estimated_transaction_volume,data=bc,color='green')
plt.show()

# %%
sns.jointplot(x=bc.btc_market_price,y=bc.btc_estimated_transaction_volume_usd,data=bc,color='green')
plt.show()

# %% [markdown]
# **Preparing the dataset**
#
#
# **extracting the dependent an independent variables.**

# %%
bc.isnull().sum()
# Out:
# Date                                                    0
# btc_market_price                                        0
# btc_total_bitcoins                                     27
# btc_market_cap                                          0
# btc_trade_volume                                       21
# btc_blocks_size                                        29
# btc_avg_block_size                                      0
# btc_n_orphaned_blocks                                   0
# btc_n_transactions_per_block                            0
# btc_median_confirmation_time                           12
# btc_hash_rate                                           0
# btc_difficulty                                         16
# btc_miners_revenue                                      0
# btc_transaction_fees                                   10
# btc_cost_per_transaction_percent                        0
# btc_cost_per_transaction                                0
# ...

# %%
x=bc.iloc[:,2:].values
y=bc.iloc[:,1].values

# %% [markdown]
# **TAKING CARE OF MISSING DATA**

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
imputer.fit(x)
x=imputer.transform(x)

# %% [markdown]
# **Splitting the DATAET In to TRAINING AND TEST SETS**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# **Trainging the simple linear regression model on training set**

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Predicting the test results**

# %%
y_pred=regressor.predict(x_test)

# %% [markdown]
# **Evaluating the model performance **

# %%
import sklearn
mse = sklearn.metrics.mean_squared_error(y_test,y_pred)
print(f'Mean Squared Error is : {mse}')
# Out:
# Mean Squared Error is : 388.95772521876427
